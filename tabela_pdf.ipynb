# %%
import tabula

# %%
tabelaComum = tabula.read_pdf("klabin.pdf", 
                              pages = '25') #guess = False e lattice = True

# %%
tabelaComum[0]
# Out:
#                                   R$ milhões     4T22     3T22     4T21  \
# 0                           EBITDA Ajustado1    1.905    2.311    1.884
# 1                                 (-) Capex2  (1.582)  (1.691)  (1.159)
# 2   (-) Contratos de arrendamentos - IFRS 16     (66)     (65)     (48)
# 3                  (-) Juros Pagos/Recebidos     (21)    (334)    (286)
# 4                  (-) Imposto de Renda e CS    (145)     (81)    (193)
# 5          (+/-) Variação no Capital de Giro      388    (164)     (43)
# 6                       (-) Dividendos & JCP    (502)    (399)    (402)
# 7                               (+/-) Outros      190        8       30
# 8                       Fluxo de Caixa Livre      167    (415)    (216)
# 9                           Dividendos & JCP      502      399      402
# 10                           Projeto Puma II      793      934      759
# 11          Projetos Especiais e de Expansão      290      267      119
# ...
