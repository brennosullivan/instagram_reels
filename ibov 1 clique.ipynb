# %%
import pandas as pd
import yfinance as yf 
import quantstats as qs

ibov = yf.download('^BVSP', "2000-01-01")['Adj Close']
retornos = ibov.resample("M").last().pct_change().dropna()
qs.extend_pandas()
retornos.plot_monthly_heatmap()
# Out:
# [*********************100%***********************]  1 of 1 completed
